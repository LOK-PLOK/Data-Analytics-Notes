# %% [markdown]
# # 📌 NumPy, Matplotlib, and Pandas Summary

# %% [markdown]
# #### Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Numpy (Numerical Python)
# NumPy is a library for numerical computing with support for multi-dimensional arrays and mathematical operations.
#
# Key Features:
# - `ndarray`: Efficient multi-dimensional arrays.
# - Mathematical operations: `sum()`, `mean()`, `std()`, `max()`, `min()`, etc.
# - Indexing & Slicing: Access parts of arrays efficiently.
# - Broadcasting: Perform operations on arrays of different shapes.

# %%
arr = np.array([1, 2, 3, 4, 5])  # Create array  
print(arr.shape)  # Check shape  

# Operations  
arr2 = arr * 2  # Multiply elements  
arr3 = np.sqrt(arr)  # Square root
# Out:
# (5,)

# %% [markdown]
# # Matplotlib (Data Visualization)
# Matplotlib is a plotting library for Python, used to create graphs and charts.
#
# ✅ Key Plot Types:
# - Line Plot: `plt.plot(x, y)`
# - Bar Chart: `plt.bar(categories, values)`
# - Histogram: `plt.hist(data, bins=n)`
# - Scatter Plot: `plt.scatter(x, y)`
#
# 🔹 Customization Options:
# - Title & Labels: `plt.title()`, `plt.xlabel()`, `plt.ylabel()`
# - Legend: `plt.legend()`
# - Grid: `plt.grid(True)`
# - Colors & Styles: `color`, `linestyle`, `marker`

# %% [markdown]
# ## Basic Example

# %%
x = [1, 2, 3, 4, 5]  
y = [10, 20, 25, 30, 40]  

plt.plot(x, y, marker='o', linestyle='--', color='b', label="Data")  
plt.xlabel("X Axis")  
plt.ylabel("Y Axis")  
plt.title("Line Plot Example")  
plt.legend()  
plt.grid(True)  
plt.show()

# %% [markdown]
# ## Bar Chart example:

# %%
categories = ['A', 'B', 'C', 'D']  
values = [5, 8, 12, 7]  

plt.bar(categories, values, color='g')  
plt.xlabel("Categories")  
plt.ylabel("Values")  
plt.title("Bar Chart Example")  
plt.show()

# %% [markdown]
# ## Histogram Example

# %%
data = np.random.randn(1000)  # Generate random data  
plt.hist(data, bins=30, color='purple', edgecolor='black')  
plt.xlabel("Values")  
plt.ylabel("Frequency")  
plt.title("Histogram Example")  
plt.show()

# %% [markdown]
# # Pandas (Data Manipulation & Analysis)
# Pandas is a library for handling structured tabular data using DataFrames and Series.
#
# ✅ Key Features:
# - `Series`: 1D labeled array.
# - `DataFrame`: 2D table (like an Excel sheet).
# - Reading/Writing Files: Supports `.csv`, `.xlsx`, `.json`, etc.
# - Filtering & Indexing: Select and modify data easily.
# - Aggregation: Sum, mean, count, etc.

# %% [markdown]
# ## Basic Usage

# %%
# Create DataFrame  
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}  
df = pd.DataFrame(data)  

print(df)  # Display DataFrame  
print(df['Age'].mean())  # Calculate mean age
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 30.0

# %% [markdown]
# ## Reading a CSV File:

# %%
df = pd.read_csv('data.csv')   # this will error because there is no data
print(df.head())  # Show first 5 rows
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df = pd.read_csv('data.csv')   # this will error because there is no data
#       2 print(df.head())  # Show first 5 rows
#
# ...

# %% [markdown]
# ## Filtering Data:

# %%
filtered_df = df[df['Age'] > 25]  # Get rows where Age > 25  
print(filtered_df)
# Out:
#       Name  Age
# 1      Bob   30
# 2  Charlie   35

# %% [markdown]
# ## Adding a new column:

# %%
df['Salary'] = [50000, 60000, 55000]  # Add a new column  
print(df)
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   55000

# %% [markdown]
# ## GroupBy & Aggregation:

# %%
df.groupby('Category')['Sales'].sum()  # Sum sales by category
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.groupby('Category')['Sales'].sum()  # Sum sales by category
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %% [markdown]
# # Comparison
# | Feature       | NumPy                  | Matplotlib          | Pandas               |
# |--------------|-----------------------|--------------------|---------------------|
# | Data Type    | Arrays                | Charts & Graphs   | DataFrames         |
# | Use Case     | Numerical Computation | Data Visualization | Data Manipulation |
# | Key Functions | `np.array()`, `np.mean()`, `np.sum()` | `plt.plot()`, `plt.bar()`, `plt.hist()` | `df.head()`, `df.groupby()`, `df.filter()` |
